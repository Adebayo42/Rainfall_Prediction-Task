# %%
### Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier, StackingClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, classification_report
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import warnings
import bayes_opt
from scipy.stats import rankdata

# %%
warnings.filterwarnings("ignore")

# %%
## read the train dataset
rainfall_df = pd.read_csv("./train.csv")

test_df = pd.read_csv("./test.csv")

sample_submission = pd.read_csv("./sample_submission.csv")

# %%
def explore_data(df):
    
    ## Check dataset shape
    print(f"****** Explore dataset shape*****\n\
The dataset has {df.shape[0]:,} rows and {df.shape[1]:,} colmns")
    
    ## Check for duplicates in dataset
    print(f"\nThere are {df.duplicated().sum():,} duplicated records in the dataset")
    
    ## Check for missing values
    print("\nCheck missing values in dataset\nColumn name: Value")
    for col in df.columns:
        print(f"{col}: {df[col].isna().sum():,} missing values")
        
    ## Check Data Information
    print("\n***** Data Information *****")
    print(f"{df.info()}")
    
    ## Check Data Statistics
    print(f"\nStatistics Data\n{df.describe()}")
    
    ## Explore the target variable distribution
    plt.figure(figsize=(4,3))
    sns.countplot(data=df, x=df.columns[-1])
    plt.title("Distribution of target variable")
    plt.xlabel("Class")
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()

# %%
## call the explore function
explore_data(rainfall_df)
# Out:
# ****** Explore dataset shape*****
# The dataset has 2,190 rows and 13 colmns
#
# There are 0 duplicated records in the dataset
#
# Check missing values in dataset
# Column name: Value
# id: 0 missing values
# day: 0 missing values
# pressure: 0 missing values
# maxtemp: 0 missing values
# temparature: 0 missing values
# mintemp: 0 missing values
# dewpoint: 0 missing values
# humidity: 0 missing values
# cloud: 0 missing values
# sunshine: 0 missing values
# winddirection: 0 missing values
# windspeed: 0 missing values
# rainfall: 0 missing values
#
# ***** Data Information *****
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2190 entries, 0 to 2189
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             2190 non-null   int64
#  1   day            2190 non-null   int64
#  2   pressure       2190 non-null   float64
#  3   maxtemp        2190 non-null   float64
# ...

# %%
## Separate features from target variable
rainfall = rainfall_df.drop(columns=["id","rainfall"], axis=1)
target = rainfall_df[["rainfall"]]

### Resample the trainset to jandle class imbalace
X_resampled, target_resampled = SMOTE(random_state=42).fit_resample(rainfall, target)

# %%
# solution 1

## Build the objective function for the model

def rfc(n_estimators,max_depth,criterion, max_features ):
    
    criterions = ["gini", "entropy", "log_loss"] 
    max_feature = ["sqrt", "log2"]
    
    params = {
        "n_estimators" : int(round(n_estimators)),
        "max_depth" : int(round(max_depth)),
        "criterion" : criterions[int(round(criterion))],
        "max_features" : max_feature[int(round(max_features))]
    }
    
    ### Use Stratified-10-fold
    strf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42) 
    
    roc_scores = []
    for train_index, val_index in strf.split(X_resampled,target_resampled):
        
        model = RandomForestClassifier(**params)
        model.fit(X_resampled.iloc[train_index], target_resampled.iloc[train_index])
        pred_proba = model.predict_proba(X_resampled.iloc[val_index])[:,1]
        val_roc_auc = roc_auc_score(target_resampled.iloc[val_index], pred_proba)
        roc_scores.append(val_roc_auc)
        
    return np.mean(roc_scores)

### Set the search space
pbound = {
    "n_estimators" : (100, 1000),
    "max_depth" : (3,15),
    "criterion" : (0,2),
    "max_features" : (0,1)
}

bayes_optmz = bayes_opt.BayesianOptimization(f=rfc, pbounds=pbound, verbose=2)

bayes_optmz.maximize(init_points=20 ,n_iter=40)
# Out:
# |   iter    |  target   | criterion | max_depth | max_fe... | n_esti... |
# -------------------------------------------------------------------------
# | 1         | 0.93      | 1.041     | 5.503     | 0.7847    | 758.9     |
# | 2         | 0.9359    | 0.07648   | 7.089     | 0.09555   | 857.0     |
# | 3         | 0.9239    | 1.042     | 5.286     | 0.4994    | 363.6     |
# | 4         | 0.9458    | 0.4739    | 9.259     | 0.5753    | 703.0     |
# | 5         | 0.9558    | 0.7441    | 14.12     | 0.8383    | 104.5     |
# | 6         | 0.9301    | 1.932     | 6.206     | 0.3966    | 498.9     |
# | 7         | 0.9541    | 0.202     | 12.46     | 0.0924    | 862.9     |
# | 8         | 0.9521    | 1.26      | 11.01     | 0.7496    | 907.9     |
# | 9         | 0.9565    | 1.474     | 13.65     | 0.8172    | 785.2     |
# | 10        | 0.9235    | 0.4628    | 5.222     | 0.4806    | 825.3     |
# | 11        | 0.9491    | 1.231     | 10.03     | 0.9825    | 675.1     |
# ...

# %%
## Fetch the best model parameters
best_params = bayes_optmz.max["params"]

## convert the parameters to integer
for i in best_params.keys():    
    best_params[i] = int(round(best_params[i]))
    
## update the best parameter values with the actual parameter
criterions = ["gini", "entropy", "log_loss"] 
max_feature = ["sqrt", "log2"]
best_params["criterion"] = criterions[best_params["criterion"]]
best_params["max_features"] = max_feature[best_params["max_features"]]

# %%
## handle the missing data in the test set using linear interpolation
for col in test_df.columns:
    if test_df[col].isna().sum() >=1:
        test_df[col].interpolate()
        
## drop the id column in the test set
test_df.drop(columns=["id"], inplace=True)

# %%
pred_rf_clf = np.zeros(len(test_df))
oof_pred_rf = np.zeros(len(X_resampled))
fold_train_auc = []
fold_val_auc = []

fold = 10
stkfold = StratifiedKFold(n_splits=fold, shuffle=True, random_state=42)

for train_idx, val_index in stkfold.split(X_resampled,target_resampled):
    
    ## index the train and validation_set
    X_train = X_resampled.iloc[train_idx]
    Y_train = target_resampled.iloc[train_idx]
    X_val = X_resampled.iloc[val_index]
    Y_val = target_resampled.iloc[val_index]
    
    ## Initialize the model
    model = RandomForestClassifier(**best_params, random_state=42)
    
    ## Fit the model
    model.fit(X_train, Y_train)
    
    ## model prediction on trainset
    pred_xtrain = model.predict_proba(X_train)[:,1]
    xtrain_roc_auc = roc_auc_score(Y_train, pred_xtrain)
    fold_train_auc.append(xtrain_roc_auc)
    
    ## model prediction on validation set
    pred_xval = model.predict_proba(X_val)[:,1]
    xval_roc_auc = roc_auc_score(Y_val, pred_xval)
    fold_val_auc.append(xval_roc_auc)
    
    ## update the oof dataset prediction
    oof_pred_rf[val_index] = pred_xval
    
    ## make prediction on the test dataset
    pred_rf_clf += model.predict_proba(test_df)[:,1]

# %%
## update the sample submission prediction with the model average prediction
sample_submission.rainfall = pred_rf_clf/fold

# %%
## round prediction to 1 decimal place
sample_submission.rainfall=sample_submission.rainfall.round(1)

## save prediction data to file
# sample_submission.to_csv("submission.csv")

# %%
## Load the best performing leaderboad submission
best_lb = pd.read_csv("./submission_best.csv")

## add weight to the predictions
sample_submission.rainfall= (-1 * sample_submission.rainfall) + (2 * best_lb.rainfall)

# %%
sample_submission.rainfall = rankdata(sample_submission.rainfall)/len(sample_submission)

# %%
sample_submission.to_csv("new_sub2.csv", index=False)

# %%
## Second solution

### define the objective function for the xgb classifier

def xgb(n_estimators,max_depth, learning_rate, subsample,colsample_bytree,gamma,reg_alpha,reg_lambda):
    
    ## create the model parameter dictionary
    params = {"n_estimators": int(round(n_estimators)),
              "max_depth" : int(round(max_depth)),
              "learning_rate": learning_rate,
              "subsample" : subsample,
              "colsample_bytree" : colsample_bytree,
              "eval_metric" : "auc",
              "random_state" : 42,
              "gamma" : gamma,
              "reg_alpha" : reg_alpha,
              "reg_lambda" : reg_lambda,
              "early_stopping_rounds" : 100
              }
    ## use stratified-10fold 
    fold =10
    stkfold = StratifiedKFold(n_splits=fold, shuffle=True, random_state=42)
    val_auc_score = []
    
    for train_idx_2, val_index_2 in stkfold.split(X_resampled,target_resampled):
        X_train = X_resampled.iloc[train_idx_2]
        Y_train = target_resampled.iloc[train_idx_2]
        X_val = X_resampled.iloc[val_index_2]
        Y_val = target_resampled.iloc[val_index_2]
        
        ## initiatile the model
        model = XGBClassifier(**params)
        
        ## fit the model
        model.fit(X_train, Y_train, eval_set = [(X_val, Y_val)])
        
        ## make prediction on the validation set
        prediction = model.predict_proba(X_val)[:,1]
        roc_auc = roc_auc_score(Y_val,prediction)
        
        ## append the score to the list
        val_auc_score.append(roc_auc)
        
        
        return np.mean(val_auc_score)
    


## defind the search space    
pbound = {"n_estimators": (100,1000),
          "max_depth" : (3,15),
          "learning_rate" : (0.01, 0.1),
          "subsample" : (0.8, 1),
          "colsample_bytree" : (0.8, 1),
          "gamma" : (0,1),
          "reg_alpha" : (0,1),
          "reg_lambda": (0,1)
          }

## Initiatize the optimization
bayest_optmz_2 = bayes_opt.BayesianOptimization(f=xgb, pbounds=pbound, random_state=42,verbose=2)

## Run the optimaztion
bayest_optmz_2.maximize(init_points=20 ,n_iter=40)
# Out:
# |   iter    |  target   | colsam... |   gamma   | learni... | max_depth | n_esti... | reg_alpha | reg_la... | subsample |
# -------------------------------------------------------------------------------------------------------------------------
# [0]	validation_0-auc:0.89456
# [1]	validation_0-auc:0.91890
# [2]	validation_0-auc:0.93129
# [3]	validation_0-auc:0.93350
# [4]	validation_0-auc:0.93535
# [5]	validation_0-auc:0.93927
# [6]	validation_0-auc:0.94264
# [7]	validation_0-auc:0.94187
# [8]	validation_0-auc:0.94382
# [9]	validation_0-auc:0.94582
# [10]	validation_0-auc:0.94531
# [11]	validation_0-auc:0.94702
# [12]	validation_0-auc:0.95006
# [13]	validation_0-auc:0.94911
# [14]	validation_0-auc:0.94793
# [15]	validation_0-auc:0.94790
# [16]	validation_0-auc:0.94819
# [17]	validation_0-auc:0.95137
# [18]	validation_0-auc:0.95118
# [19]	validation_0-auc:0.95045
# [20]	validation_0-auc:0.95093
# [21]	validation_0-auc:0.95056
# [22]	validation_0-auc:0.95247
# ...

# %%
## fetch the best parameters
best_params_2 = bayest_optmz_2.max["params"]

## format the best paramaters
best_params_2["max_depth"]=int(round(best_params_2["max_depth"]))
best_params_2["n_estimators"]=int(round(best_params_2["n_estimators"]))
best_params_2["eval_metric"] = "auc"
best_params_2["early_stopping_rounds"] = 100

# %%
## Build the model using the best parameters

pred_xgb_clf = np.zeros(len(test_df))
oof_pred_xgb = np.zeros(len(X_resampled))
fold_train_auc = []
fold_val_auc = []

fold = 10
stkfold = StratifiedKFold(n_splits=fold, shuffle=True, random_state=42)

for train_idx, val_index in stkfold.split(X_resampled,target_resampled):
    
    ## index the train and validation_set
    X_train = X_resampled.iloc[train_idx]
    Y_train = target_resampled.iloc[train_idx]
    X_val = X_resampled.iloc[val_index]
    Y_val = target_resampled.iloc[val_index]
    
    ## Initialize the model
    model = XGBClassifier(**best_params_2, random_state=42)
    
    ## Fit the model
    model.fit(X_train, Y_train, eval_set=[(X_val,Y_val)])
    
    ## model prediction on trainset
    pred_xtrain = model.predict_proba(X_train)[:,1]
    xtrain_roc_auc = roc_auc_score(Y_train, pred_xtrain)
    fold_train_auc.append(xtrain_roc_auc)
    
    ## model prediction on validation set
    pred_xval = model.predict_proba(X_val)[:,1]
    xval_roc_auc = roc_auc_score(Y_val, pred_xval)
    fold_val_auc.append(xval_roc_auc)
    
    ## update the oof dataset prediction
    oof_pred_xgb[val_index] = pred_xval
    
    ## make prediction on the test dataset
    pred_xgb_clf += model.predict_proba(test_df)[:,1]
# Out:
# [0]	validation_0-auc:0.91019
# [1]	validation_0-auc:0.91712
# [2]	validation_0-auc:0.92393
# [3]	validation_0-auc:0.92204
# [4]	validation_0-auc:0.92902
# [5]	validation_0-auc:0.93080
# [6]	validation_0-auc:0.93036
# [7]	validation_0-auc:0.93344
# [8]	validation_0-auc:0.93864
# [9]	validation_0-auc:0.93963
# [10]	validation_0-auc:0.93969
# [11]	validation_0-auc:0.94138
# [12]	validation_0-auc:0.94116
# [13]	validation_0-auc:0.94028
# [14]	validation_0-auc:0.94105
# [15]	validation_0-auc:0.94255
# [16]	validation_0-auc:0.94446
# [17]	validation_0-auc:0.94560
# [18]	validation_0-auc:0.94663
# [19]	validation_0-auc:0.94663
# [20]	validation_0-auc:0.94586
# [21]	validation_0-auc:0.94788
# [22]	validation_0-auc:0.94865
# [23]	validation_0-auc:0.94817
# [24]	validation_0-auc:0.94784
# [25]	validation_0-auc:0.94891
# [26]	validation_0-auc:0.94839
# [27]	validation_0-auc:0.95001
# [28]	validation_0-auc:0.95023
# [29]	validation_0-auc:0.95071
# [30]	validation_0-auc:0.95177
# ...

# %%
## update the sample submission prediction with the model average prediction
sample_submission.rainfall = pred_rf_clf/fold

## round prediction to 1 decimal place
sample_submission.rainfall=sample_submission.rainfall.round(1)

## save prediction data to file
sample_submission.to_csv("submission1.csv")

# %%
## read the submission file to improve leader board score
sub1 = pd.read_csv("./submission.csv")
sub2 = pd.read_csv("./submission1.csv")

## calculate the weights
randomforest_weight = (0.86430/(0.86430 + 0.81268))
xgb_weight = (0.81268/(0.86430 + 0.81268))
sub_merged = sub1.copy()

## Final submission
sub_merged.rainfall = (randomforest_weight * sub1.rainfall) + (xgb_weight * sub2.rainfall)

## round to 1 decimal place
sub_merged.rainfall = sub_merged.rainfall.round(1)

## save to file
sub_merged.to_csv("submission2.csv")

# %%
from sklearn.linear_model import LogisticRegression


# Stack predictions as features
stacked_train = np.column_stack((oof_pred_rf, oof_pred_xgb))
stacked_test = np.column_stack((pred_rf_clf, pred_xgb_clf))

# Train a meta-model (Logistic Regression)
meta_learner = LogisticRegression()
meta_learner.fit(stacked_train, target_resampled)

# Predict final test set probabilities
final_pred = meta_learner.predict_proba(stacked_test)[:, 1]

## update the sample submission prediction with the model average prediction
sample_submission.rainfall = final_pred

## round prediction to 1 decimal place
sample_submission.rainfall=sample_submission.rainfall.round(1)

## save prediction data to file
sample_submission.to_csv("submission3.csv")

# %%
## Split dataset to train and test set using 70% trainset
X_train, X_test, Y_train, Y_test = train_test_split(rainfall,target, train_size=0.7)

# %%
## Resample datset to handle class imbalance
X_resamples, Y_train_clean = SMOTE(random_state=42).fit_resample(X_train, Y_train)

## Scale the features values
scaler = StandardScaler()
X_train_clean = scaler.fit_transform(X_resamples)
X_test_clean = scaler.transform(X_test)

# %%
## Create disctionary for models

stacked_classifier = StackingClassifier(estimators=[("RandomFOrest", RandomForestClassifier()),
                                                     ("GradientBoosting", GradientBoostingClassifier(subsample=0.9, random_state=42)),
                                                     ("LightGBM", LGBMClassifier(subsample=0.9, random_state=42))],
                                        final_estimator=GradientBoostingClassifier(random_state=42))

models = {"RandomForest": RandomForestClassifier(n_estimators=100,random_state=42), 
          "GradientClassifier": GradientBoostingClassifier(n_estimators=100,subsample=0.9, random_state=42),
          "XGBClassifier": XGBClassifier(), "LGBMClassifier": LGBMClassifier(n_estimators=100, subsample=0.9,random_state=42), 
          "Stacked_Classifier": stacked_classifier}

for model, classifier in models.items():
    classifier.fit(X_train_clean,Y_train_clean )
    
    ## Check model accuracy
    prediction = classifier.predict(X_test_clean)
    prediction_prob = classifier.predict_proba(X_test_clean)
    accuracy = accuracy_score(Y_test, prediction)
    roc_auc = roc_auc_score(Y_test, prediction_prob[:,1])
    print(f"The accuracy of {model} classifier is: {accuracy:4f}")
    print(f"The roc_auc_score of {model} classifier is: {roc_auc:4f}\n")
    
    ## Confusion Matix
    plt.Figure(figsize=(4,3))
    sns.heatmap(confusion_matrix(Y_test, prediction), fmt=",",cmap="Blues",annot=True)
    plt.title(f"Confusion Matrix - {model}")
    plt.xlabel("Actual")
    plt.ylabel("Prediction")
    plt.tight_layout
    plt.show()
# Out:
# The accuracy of RandomForest classifier is: 0.852359
# The roc_auc_score of RandomForest classifier is: 0.890416
# The accuracy of GradientClassifier classifier is: 0.846271
# The roc_auc_score of GradientClassifier classifier is: 0.898731
# The accuracy of XGBClassifier classifier is: 0.850837
# The roc_auc_score of XGBClassifier classifier is: 0.876534
# [LightGBM] [Info] Number of positive: 1158, number of negative: 1158
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000279 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2779
# [LightGBM] [Info] Number of data points in the train set: 2316, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# The accuracy of LGBMClassifier classifier is: 0.837139
# The roc_auc_score of LGBMClassifier classifier is: 0.886967
# [LightGBM] [Info] Number of positive: 1158, number of negative: 1158
# ...
